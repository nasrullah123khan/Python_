# %%
#Pandas revision

# %%
import pandas as pd

# %%
frame = pd.read_csv('std.csv')

# %%
frame['scaled marks']=frame['Total (100)'].apply(lambda x:x+5)

# %%
frame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 20  022-14-110412  BS(CS)                  Muhammad Aamir   24     7.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 22  022-14-110398  BS(CS)               Muhammad Abdullah   20     7.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# 27  022-14-110452  BS(CS)             Muhammad Osama Khan   27     8.0
# 28  022-14-110387  BS(CS)          Muhammad Saqib Intizar   22     6.0
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 30  022-14-110401  BS(CS)                 Muhammad Shozab   23     8.0
# 31  022-14-110231  BS(CS)           Muhammad Taha Hasnain   27     7.0
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 34  022-14-110413  BS(CS)                Nazeer Bin Zafar   25     9.0
# 35   022-14-19923  BS(CS)                      Rabi Ahmed   20     8.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 6                     44        30.0           74     B            79
# 7                     45        40.0           85     A            90
# 8                     37        24.0           61     C            66
# 9                     44        40.0           84     A            89
# 10                    46        45.0           91     A            96
# 11                    41        35.0           76     B            81
# 12                    40        33.0           73     B            78
# 13                    42        25.0           67     C            72
# 14                    36        29.0           65     C            70
# 15                    18         NaN           18     F            23
# 16                    37        35.0           72     B            77
# 17                    39        31.0           70     B            75
# 18                    31        29.0           60     C            65
# 19                    46        45.0           91     A            96
# 20                    40        31.0           71     B            76
# 21                    40        20.0           60     C            65
# 22                    34        23.0           57     F            62
# 23                    41        21.0           62     C            67
# 24                    44        33.0           77     B            82
# 25                    45        41.0           86     A            91
# 26                    41        24.0           65     C            70
# 27                    45        26.0           71     B            76
# 28                    39        18.0           57     F            62
# 29                    30         9.0           39     F            44
# 30                    40        32.0           72     B            77
# 31                    44        29.0           73     B            78
# 32                    21         8.0           29     F            34
# 33                    34        17.0           51     F            56
# 34                    44        42.0           86     A            91
# 35                    38        28.0           66     C            71
# 36                    43        27.0           70     B            75
# 37                    45        30.0           75     B            80
# 38                    22        17.0           39     F            44
# 39                    43        25.0           68     C            73
# 40                    46        35.0           81     A            86
# 41                    37        20.0           57     F            62
# 42                    44        23.0           67     C            72
# 43                    45        34.0           79     B            84
# 44                    41        22.0           63     C            68
# 45                    45        35.0           80     A            85
# 46                    43        22.0           65     C            70
# 47                    27        19.0           46     F            51

# %%
#Lambda function

# %%
y = lambda x:2*x  #lambda arg: operation

# %%
y(6)
# Out:
# 12

# %%
frame['Total (100)'].count()
# Out:
# 48

# %%
frame['Total (100)'].argmin()
# Out:
# 15

# %%
def min(row):
    if row['Assignment 1']>row['Assignment 2']:
        return row['Assignment 2']
    else:
        return row['Assignment 1']
frame.apply(min,axis=1)
# Out:
# 0      7.0
# 1      8.0
# 2      8.0
# 3      NaN
# 4      7.0
# 5      8.0
# 6      8.0
# 7      8.0
# 8      7.0
# 9      8.0
# 10     8.0
# 11     5.0
# 12     8.0
# 13     8.0
# 14     6.0
# 15     NaN
# 16     7.0
# 17     9.0
# 18     8.0
# 19     8.0
# 20     7.0
# 21     9.0
# 22     7.0
# 23     8.0
# 24     9.0
# 25     8.0
# 26     6.0
# 27     8.0
# 28     9.0
# 29     6.0
# 30     9.0
# 31    10.0
# 32     8.0
# 33     8.0
# 34     8.0
# 35     NaN
# 36     9.0
# 37     9.0
# 38     5.0
# 39     9.0
# 40     8.0
# 41     8.0
# 42     8.0
# 43     6.0
# 44     9.0
# 45     9.0
# 46     8.0
# 47     5.0
# dtype: float64

# %%
#Assignment: Read data in different formats

# %%
frame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 20  022-14-110412  BS(CS)                  Muhammad Aamir   24     7.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 22  022-14-110398  BS(CS)               Muhammad Abdullah   20     7.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# 27  022-14-110452  BS(CS)             Muhammad Osama Khan   27     8.0
# 28  022-14-110387  BS(CS)          Muhammad Saqib Intizar   22     6.0
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 30  022-14-110401  BS(CS)                 Muhammad Shozab   23     8.0
# 31  022-14-110231  BS(CS)           Muhammad Taha Hasnain   27     7.0
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 34  022-14-110413  BS(CS)                Nazeer Bin Zafar   25     9.0
# 35   022-14-19923  BS(CS)                      Rabi Ahmed   20     8.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 40  022-14-110584  BS(CS)                     Sharif Taqi   27     9.0
# 41  022-14-110225  BS(CS)                   Shariqa Ahmad   20     7.0
# 42  022-14-110587  BS(CS)                   Sumbul Rehman   28     5.0
# 43  022-14-110451  BS(CS)               Syed Faizan Uddin   28     9.0
# 44  022-14-110589  BS(CS)                     Syed Sohaib   25     7.0
# 45  022-14-110400  BS(CS)               Syeda Sabika Raza   27     9.0
# 46   022-14-19911  BS(CS)                      Usman Khan   25     8.0
# 22                    34        23.0           57     F            62
# 23                    41        21.0           62     C            67
# 24                    44        33.0           77     B            82
# 25                    45        41.0           86     A            91
# 26                    41        24.0           65     C            70
# 27                    45        26.0           71     B            76
# 28                    39        18.0           57     F            62
# 29                    30         9.0           39     F            44
# 30                    40        32.0           72     B            77
# 31                    44        29.0           73     B            78
# 32                    21         8.0           29     F            34
# 33                    34        17.0           51     F            56
# 34                    44        42.0           86     A            91
# 35                    38        28.0           66     C            71
# 36                    43        27.0           70     B            75
# 37                    45        30.0           75     B            80
# 38                    22        17.0           39     F            44
# 39                    43        25.0           68     C            73
# 40                    46        35.0           81     A            86
# 41                    37        20.0           57     F            62
# 42                    44        23.0           67     C            72
# 43                    45        34.0           79     B            84
# 44                    41        22.0           63     C            68
# 45                    45        35.0           80     A            85
# 46                    43        22.0           65     C            70
# 47                    27        19.0           46     F            51

# %%
frame = pd.read_csv('students.csv',index_col='Student Code')
display(frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 frame = pd.read_csv('students.csv',index_col='Student Code')
#       2 display(frame)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:311, in CParserWrapper.read(self, nrows)
#     308     data = {k: v for k, (i, v) in zip(names, data_tups)}
#     310     names, date_data = self._do_date_conversions(names, data)
# --> 311     index, names = self._make_index(date_data, alldata, names)
#     313 # maybe create a mi on the columns
#     314 conv_names = self._maybe_make_multi_index_columns(names, self.col_names)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\base_parser.py:389, in ParserBase._make_index(self, data, alldata, columns, indexnamerow)
#     386     index = None
#     388 elif not self._has_complex_date_col:
# --> 389     index = self._get_simple_index(alldata, columns)
#     390     index = self._agg_index(index)
#     391 elif self._has_complex_date_col:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\base_parser.py:421, in ParserBase._get_simple_index(self, data, columns)
#     419 index = []
#     420 for idx in self.index_col:
# --> 421     i = ix(idx)
#     422     to_remove.append(i)
#     423     index.append(data[i])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\base_parser.py:416, in ParserBase._get_simple_index.<locals>.ix(col)
#     414 if not isinstance(col, str):
#     415     return col
# --> 416 raise ValueError(f"Index {col} invalid")
#
# ValueError: Index Student Code invalid

# %%
#Removing outliers

# %%
import numpy as np
mean = frame['Total (100)'].mean()
std = frame['Total (100)'].std()
lower_range = mean - 3*std
upper_range = mean + 3*std

# %%
filtered_data = frame[frame['Total (100)'] < upper_range][frame['Total (100)'] > lower_range]

# %%
filtered_data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 20  022-14-110412  BS(CS)                  Muhammad Aamir   24     7.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 22  022-14-110398  BS(CS)               Muhammad Abdullah   20     7.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# 27  022-14-110452  BS(CS)             Muhammad Osama Khan   27     8.0
# 28  022-14-110387  BS(CS)          Muhammad Saqib Intizar   22     6.0
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 30  022-14-110401  BS(CS)                 Muhammad Shozab   23     8.0
# 31  022-14-110231  BS(CS)           Muhammad Taha Hasnain   27     7.0
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 34  022-14-110413  BS(CS)                Nazeer Bin Zafar   25     9.0
# 35   022-14-19923  BS(CS)                      Rabi Ahmed   20     8.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 40  022-14-110584  BS(CS)                     Sharif Taqi   27     9.0
# 41  022-14-110225  BS(CS)                   Shariqa Ahmad   20     7.0
# 42  022-14-110587  BS(CS)                   Sumbul Rehman   28     5.0
# 18                    31        29.0           60     C            65
# 19                    46        45.0           91     A            96
# 20                    40        31.0           71     B            76
# 21                    40        20.0           60     C            65
# 22                    34        23.0           57     F            62
# 23                    41        21.0           62     C            67
# 24                    44        33.0           77     B            82
# 25                    45        41.0           86     A            91
# 26                    41        24.0           65     C            70
# 27                    45        26.0           71     B            76
# 28                    39        18.0           57     F            62
# 29                    30         9.0           39     F            44
# 30                    40        32.0           72     B            77
# 31                    44        29.0           73     B            78
# 32                    21         8.0           29     F            34
# 33                    34        17.0           51     F            56
# 34                    44        42.0           86     A            91
# 35                    38        28.0           66     C            71
# 36                    43        27.0           70     B            75
# 37                    45        30.0           75     B            80
# 38                    22        17.0           39     F            44
# 39                    43        25.0           68     C            73
# 40                    46        35.0           81     A            86
# 41                    37        20.0           57     F            62
# 42                    44        23.0           67     C            72
# 43                    45        34.0           79     B            84
# 44                    41        22.0           63     C            68
# 45                    45        35.0           80     A            85
# 46                    43        22.0           65     C            70
# 47                    27        19.0           46     F            51

# %%
frame['Assignment 1'].fillna(frame['Assignment 1'].mean(),inplace=True)

# %%
frame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 20  022-14-110412  BS(CS)                  Muhammad Aamir   24     7.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 22  022-14-110398  BS(CS)               Muhammad Abdullah   20     7.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# 27  022-14-110452  BS(CS)             Muhammad Osama Khan   27     8.0
# 28  022-14-110387  BS(CS)          Muhammad Saqib Intizar   22     6.0
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 30  022-14-110401  BS(CS)                 Muhammad Shozab   23     8.0
# 31  022-14-110231  BS(CS)           Muhammad Taha Hasnain   27     7.0
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 34  022-14-110413  BS(CS)                Nazeer Bin Zafar   25     9.0
# 35   022-14-19923  BS(CS)                      Rabi Ahmed   20     8.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 40  022-14-110584  BS(CS)                     Sharif Taqi   27     9.0
# 41  022-14-110225  BS(CS)                   Shariqa Ahmad   20     7.0
# 42  022-14-110587  BS(CS)                   Sumbul Rehman   28     5.0
# 43  022-14-110451  BS(CS)               Syed Faizan Uddin   28     9.0
# 44  022-14-110589  BS(CS)                     Syed Sohaib   25     7.0
# 45  022-14-110400  BS(CS)               Syeda Sabika Raza   27     9.0
# 46   022-14-19911  BS(CS)                      Usman Khan   25     8.0
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
#
#     Quiz 2  Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0      3.0                8      7.000000           9.0                    9
# 1      5.0                5      8.000000          10.0                   10
# 2      2.0                5      8.000000          10.0                   10
# 3      2.0                7      7.755556           2.0                    2
# 4      6.0                7      7.000000           9.0                    9
# 5      6.0                9      8.000000          10.0                   10
# 6      6.0                6      8.000000          10.0                   10
# 7      6.0                9      8.000000          10.0                   10
# 8      4.0                9      7.000000           9.0                    9
# 9      6.0                8      8.000000           NaN                    8
# 10     7.0                8      8.000000           NaN                    8
# 11     5.0                8      5.000000           NaN                    5
# 12     5.0                7      8.000000          10.0                   10
# 13     4.0                8      8.000000          10.0                   10
# 14     4.0                7      6.000000           8.0                    8
# 15     NaN                0      7.755556           NaN                    0
# 16     5.0                5      7.000000           9.0                    9
# 17     5.0                8      9.000000          11.0                   11
# 18     2.0                5      8.000000          10.0                   10
# 19     6.0                9      8.000000          10.0                   10
# 20     6.0                7      7.000000           9.0                    9
# 21     6.0                9      9.000000          11.0                   11
# 22     6.0                7      7.000000           NaN                    7
# 23     NaN                5      8.000000          10.0                   10
# 24     4.0                5      9.000000          11.0                   11
# 25     6.0                9      8.000000          10.0                   10
# 26     NaN                6      6.000000           8.0                    8
# 27     6.0                8      8.000000          10.0                   10
# 28     6.0                6      9.000000          11.0                   11
# 29     1.0                7      6.000000           NaN                    6
# 30     6.0                8      9.000000           NaN                    9
# 31     5.0                7     10.000000           NaN                   10
# 32     2.0                2      8.000000          10.0                   10
# 33     2.0                4      8.000000          10.0                   10
# 34     6.0                9      8.000000          10.0                   10
# 35     5.0                8      7.755556          10.0                   10
# 36     5.0                9      9.000000           NaN                    9
# 37     5.0                9      9.000000           NaN                    9
# 38     6.0                6      5.000000           7.0                    7
# 39     4.0                4      9.000000          11.0                   11
# 40     6.0                9      8.000000          10.0                   10
# 41     6.0                7      8.000000          10.0                   10
# 42     6.0                6      8.000000          10.0                   10
# 43     4.0                9      6.000000           8.0                    8
# 44     5.0                7      9.000000           NaN                    9
# 45     6.0                9      9.000000           NaN                    9
# 46     5.0                8      8.000000          10.0                   10
# 47     5.0                9      5.000000           7.0                    7
#
#     Total Sessional (50)  Final (50)  Total (100) Grade  scaled marks
# 0                     45        25.0           70     B            75
# 1                     32        18.0           50     F            55
# 2                     33        30.0           63     C            68
# 3                     23        23.0           46     F            51
# 4                     43        34.0           77     B            82
# 5                     44        27.0           71     B            76
# 6                     44        30.0           74     B            79
# 7                     45        40.0           85     A            90
# 8                     37        24.0           61     C            66
# 9                     44        40.0           84     A            89
# 10                    46        45.0           91     A            96
# 11                    41        35.0           76     B            81
# 12                    40        33.0           73     B            78
# 13                    42        25.0           67     C            72
# 14                    36        29.0           65     C            70
# 15                    18         NaN           18     F            23
# 16                    37        35.0           72     B            77
# 17                    39        31.0           70     B            75
# 18                    31        29.0           60     C            65
# 19                    46        45.0           91     A            96
# 20                    40        31.0           71     B            76
# 21                    40        20.0           60     C            65
# 22                    34        23.0           57     F            62
# 23                    41        21.0           62     C            67
# 24                    44        33.0           77     B            82
# 25                    45        41.0           86     A            91
# 26                    41        24.0           65     C            70
# 27                    45        26.0           71     B            76
# 28                    39        18.0           57     F            62
# 29                    30         9.0           39     F            44
# 30                    40        32.0           72     B            77
# 31                    44        29.0           73     B            78
# 32                    21         8.0           29     F            34
# 33                    34        17.0           51     F            56
# 34                    44        42.0           86     A            91
# 35                    38        28.0           66     C            71
# 36                    43        27.0           70     B            75
# 37                    45        30.0           75     B            80
# 38                    22        17.0           39     F            44
# 39                    43        25.0           68     C            73
# 40                    46        35.0           81     A            86
# 41                    37        20.0           57     F            62
# 42                    44        23.0           67     C            72
# 43                    45        34.0           79     B            84
# 44                    41        22.0           63     C            68
# 45                    45        35.0           80     A            85
# 46                    43        22.0           65     C            70
# 47                    27        19.0           46     F            51

# %%
#Database

# %%
import sqlite3 as s3

# %%
query = "create table Student(sId varchar,sname varchar)" #Create a table

# %%
con = s3.connect('student.sqlite') #Make the connection

# %%
con.execute(query) #Execute query
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 con.execute(query)
#
# OperationalError: table Student already exists

# %%
data = [
    (1,'Ali'),
    (2,'Fatima'),
    (3,'Asad')    
]

# %%
query = "INSERT INTO Student values(?,?)"

# %%
con.executemany(query,data)

# %%
con.commit()

# %%
query = "select sId, sName from Student"

# %%
cursor = con.execute(query)

# %%
rows = cursor.fetchall()

# %%
rows
# Out:
# [('1', 'Ali'), ('2', 'Fatima'), ('3', 'Asad')]

# %%
cursor.description
# Out:
# (('sId', None, None, None, None, None, None),
#  ('sname', None, None, None, None, None, None))

# %%
#DDL : Create, alter
#DML : Select, Insert, delete, update

# %%
con.close()

# %%
#Data cleaning

# %%
frame.columns
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade', 'scaled marks'],
#       dtype='object')

# %%
frame['Quiz 1'].notnull()
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32    False
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# Name: Quiz 1, dtype: bool

# %%
frame['Quiz 1'].isnull()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# Name: Quiz 1, dtype: bool

# %%
pd.set_option('display.max_rows', None)

# %%
frame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 20  022-14-110412  BS(CS)                  Muhammad Aamir   24     7.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 22  022-14-110398  BS(CS)               Muhammad Abdullah   20     7.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# 27  022-14-110452  BS(CS)             Muhammad Osama Khan   27     8.0
# 28  022-14-110387  BS(CS)          Muhammad Saqib Intizar   22     6.0
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 30  022-14-110401  BS(CS)                 Muhammad Shozab   23     8.0
# 31  022-14-110231  BS(CS)           Muhammad Taha Hasnain   27     7.0
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 34  022-14-110413  BS(CS)                Nazeer Bin Zafar   25     9.0
# 35   022-14-19923  BS(CS)                      Rabi Ahmed   20     8.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 40  022-14-110584  BS(CS)                     Sharif Taqi   27     9.0
# 41  022-14-110225  BS(CS)                   Shariqa Ahmad   20     7.0
# 42  022-14-110587  BS(CS)                   Sumbul Rehman   28     5.0
# 43  022-14-110451  BS(CS)               Syed Faizan Uddin   28     9.0
# 44  022-14-110589  BS(CS)                     Syed Sohaib   25     7.0
# 45  022-14-110400  BS(CS)               Syeda Sabika Raza   27     9.0
# 46   022-14-19911  BS(CS)                      Usman Khan   25     8.0
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
#
#     Quiz 2  Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0      3.0                8      7.000000           9.0                    9
# 1      5.0                5      8.000000          10.0                   10
# 2      2.0                5      8.000000          10.0                   10
# 3      2.0                7      7.755556           2.0                    2
# 4      6.0                7      7.000000           9.0                    9
# 5      6.0                9      8.000000          10.0                   10
# 6      6.0                6      8.000000          10.0                   10
# 7      6.0                9      8.000000          10.0                   10
# 8      4.0                9      7.000000           9.0                    9
# 9      6.0                8      8.000000           NaN                    8
# 10     7.0                8      8.000000           NaN                    8
# 11     5.0                8      5.000000           NaN                    5
# 12     5.0                7      8.000000          10.0                   10
# 13     4.0                8      8.000000          10.0                   10
# 14     4.0                7      6.000000           8.0                    8
# 15     NaN                0      7.755556           NaN                    0
# 16     5.0                5      7.000000           9.0                    9
# 47                    27        19.0           46     F            51

# %%
print(frame.count())
print(frame.dropna().count())
# Out:
# Student Code            48
# Degree                  48
# Student Name            48
# Mid                     48
# Quiz 1                  45
# Quiz 2                  45
# Best of Quizzes         48
# Assignment 1            48
# Assignment 2            36
# Best of Assignments     48
# Total Sessional (50)    48
# Final (50)              47
# Total (100)             48
# Grade                   48
# scaled marks            48
# dtype: int64
# Student Code            32
# Degree                  32
# Student Name            32
# Mid                     32
# Quiz 1                  32
# Quiz 2                  32
# Best of Quizzes         32
# Assignment 1            32
# Assignment 2            32
# Best of Assignments     32
# Total Sessional (50)    32
# Final (50)              32
# Total (100)             32
# Grade                   32
# scaled marks            32
# dtype: int64

# %%
print(frame.count())
print(frame.dropna(how='all').count())
# Out:
# Student Code            48
# Degree                  48
# Student Name            48
# Mid                     48
# Quiz 1                  45
# Quiz 2                  45
# Best of Quizzes         48
# Assignment 1            48
# Assignment 2            36
# Best of Assignments     48
# Total Sessional (50)    48
# Final (50)              47
# Total (100)             48
# Grade                   48
# scaled marks            48
# dtype: int64
# Student Code            48
# Degree                  48
# Student Name            48
# Mid                     48
# Quiz 1                  45
# Quiz 2                  45
# Best of Quizzes         48
# Assignment 1            48
# Assignment 2            36
# Best of Assignments     48
# Total Sessional (50)    48
# Final (50)              47
# Total (100)             48
# Grade                   48
# scaled marks            48
# dtype: int64

# %%
df = pd.DataFrame({'name':['ali','asif','rashid',None],'age':[1,None,3,None], 'marks':[None,12,3,25]})

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  3.0    3.0
# 3    None  NaN   25.0

# %%
df.dropna(how='all')
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  3.0    3.0
# 3    None  NaN   25.0

# %%
df.dropna(thresh=2) #atleast two columns should have the data
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  3.0    3.0

# %%
 df.dropna(thresh=3,axis=1) #atleast three rows have data to survive a column
# Out:
#      name  marks
# 0     ali    NaN
# 1    asif   12.0
# 2  rashid    3.0
# 3    None   25.0

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  3.0    3.0
# 3    None  NaN   25.0

# %%
df[df['name'].notnull()]
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  3.0    3.0

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  3.0    3.0
# 3    None  NaN   25.0

# %%
df.fillna({  #specifying different filled values for each column
    'name':'No Name',
    'age':18,
    'marks':0
})
# Out:
#       name   age  marks
# 0      ali   1.0    0.0
# 1     asif  18.0   12.0
# 2   rashid   3.0    3.0
# 3  No Name  18.0   25.0

# %%
df.fillna(0) #Filled all missing values with 0
# Out:
#      name  age  marks
# 0     ali  1.0    0.0
# 1    asif  0.0   12.0
# 2  rashid  3.0    3.0
# 3       0  0.0   25.0

# %%
df['age'].fillna(df['age'].mean()) #Filled with mean vale
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.0
# Name: age, dtype: float64

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  3.0    3.0
# 3    None  NaN   25.0

# %%
df.fillna(method='ffill')
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  1.0   12.0
# 2  rashid  3.0    3.0
# 3  rashid  3.0   25.0

# %%
df = pd.DataFrame({'name':['ali','asif','rashid',None],'age':[1,None,None,None], 'marks':[None,12,3,25]})

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  NaN    3.0
# 3    None  NaN   25.0

# %%
df.fillna(method='ffill',limit=2)
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  1.0   12.0
# 2  rashid  1.0    3.0
# 3  rashid  NaN   25.0

# %%
df = pd.DataFrame({'name':['ali','asif','rashid','rashid'],'age':[1,None,None,None], 'marks':[None,12,3,3]})

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  NaN    3.0
# 3  rashid  NaN    3.0

# %%
df.drop_duplicates()
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  NaN    3.0

# %%
df = pd.DataFrame({'name':['ali','asif','rashid','rashid'],'age':[1,None,None,None], 'marks':[None,12,3,31]})

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  NaN    3.0
# 3  rashid  NaN   31.0

# %%
df.drop_duplicates(['name'])
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  NaN    3.0

# %%
df.drop_duplicates(['name'],keep='last')
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 3  rashid  NaN   31.0

# %%
father_name={
    'ali':'Hamid',
    'asif':'Asghar',
    'rashid':'Naeem'
}

# %%
df
# Out:
#      name  age  marks
# 0     ali  1.0    NaN
# 1    asif  NaN   12.0
# 2  rashid  NaN    3.0
# 3  rashid  NaN   31.0

# %%
df['Father Name'] = df['name'].map(father_name)

# %%
df
# Out:
#      name  age  marks Father Name
# 0     ali  1.0    NaN       Hamid
# 1    asif  NaN   12.0      Asghar
# 2  rashid  NaN    3.0       Naeem
# 3  rashid  NaN   31.0       Naeem

# %%
df['Full Name'] = df['name'].map(lambda name: name+' ' +father_name[name])

# %%
df
# Out:
#      name  age  marks Father Name     Full Name
# 0     ali  1.0    NaN       Hamid     ali Hamid
# 1    asif  NaN   12.0      Asghar   asif Asghar
# 2  rashid  NaN    3.0       Naeem  rashid Naeem
# 3  rashid  NaN   31.0       Naeem  rashid Naeem
