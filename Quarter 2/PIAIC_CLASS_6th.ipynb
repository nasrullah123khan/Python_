# %%
import pandas as pd

# %%
dataframe = pd.read_csv('titanic.csv')

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataframe.rename(
columns={"PassengerId":"Id"}
)
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
dataframe[['Survived','Pclass']].sum(axis=1)
# Out:
# 0      3
# 1      2
# 2      4
# 3      2
# 4      3
#       ..
# 886    2
# 887    2
# 888    3
# 889    2
# 890    3
# Length: 891, dtype: int64

# %% [raw]
# titanic.info

# %%
dataframe.Age.mean()
# Out:
# 29.69911764705882

# %%
print(dataframe.mean())
print(dataframe.max())
print(dataframe.min())
print(dataframe.median())
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                   80.0
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                              512.3292
# dtype: object
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Name           Abbing, Mr. Anthony
# Sex                         female
# Age                           0.42
# SibSp                            0
# Parch                            0
# ...

# %%
dataframe[["Age","Fare"]].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
dataframe[["Age","Fare"]].mediann()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
dataframe.agg(
{
    "Age":{"sum", "min", "max", "median", "skew"},
    "Fare": {"min", "max", "median", "skew"}
}
)
# Out:
#                  Age        Fare
# min         0.420000    0.000000
# median     28.000000   14.454200
# sum     21205.170000         NaN
# skew        0.389108    4.787317
# max        80.000000  512.329200

# %%
dataframe.groupby(["Sex"]).agg('mean')
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
dataframe.groupby('Sex')["PassengerId", "Survived"].apply(lambda x:x.count())
# Out:
# C:\Users\Nasrullah Khan\AppData\Local\Temp\ipykernel_15224\1288269288.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dataframe.groupby('Sex')["PassengerId", "Survived"].apply(lambda x:x.count())
#         PassengerId  Survived
# Sex
# female          314       314
# male            577       577
